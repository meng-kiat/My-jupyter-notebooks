# %%
import riotwatcher
import requests

# %%
from riotwatcher import RiotWatcher
riot_watcher = RiotWatcher(api_key)

# %%
account_data = riot_watcher.account.by_riot_id("Asia", game_name="Siden", tag_line="Tesmo")

# %%
account_data
# Out:
# {'puuid': 'GzPBNH7ouvZ8xFdIMfAQZdVlgZvnI7DeBl3RKXa7sKIf5xgg-DuH_yqK2Zb9vdRlhTGGgzkB2XW7Aw',
#  'gameName': 'Siden',
#  'tagLine': 'Tesmo'}

# %%
puuid = account_data['puuid']

# %%
my_region = "sg2"
puuid = account_data['puuid']

# %%
from riotwatcher import TftWatcher
import pandas as pd
import numpy as np

api_key = 'hidden'
watcher = TftWatcher(api_key)
my_region = 'SEA'

# %%
watcher = TftWatcher(api_key)

# %%
matches_ids = watcher.match.by_puuid(my_region, puuid, count = 200)

# %%
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_base_api', '_league', '_match', '_summoner', 'league', 'match', 'summoner']

# %%
matches_ids
# Out:
# ['SG2_34716410',
#  'SG2_34598032',
#  'SG2_34457185',
#  'SG2_34327227',
#  'SG2_34192958',
#  'SG2_33960779',
#  'SG2_33744297',
#  'SG2_33525660',
#  'SG2_33423120',
#  'SG2_33383084',
#  'SG2_33340548',
#  'SG2_33304104',
#  'SG2_33260376',
#  'SG2_33155373',
#  'SG2_33070436',
#  'SG2_33045332',
#  'SG2_33021698',
#  'SG2_32997308',
#  'SG2_32934034',
#  'SG2_32881840',
#  'SG2_32840870',
#  'SG2_32796020',
#  'SG2_32754433',
#  'SG2_32703702',
#  'SG2_32658154',
#  'SG2_32610405',
#  'SG2_32546066',
#  'SG2_32509050',
#  'SG2_32450858',
#  'SG2_32416556',
#  'SG2_32355371',
#  'SG2_32298549',
#  'SG2_32224967',
#  'SG2_32196284',
#  'SG2_32190320',
#  'SG2_32166039',
#  'SG2_32156637',
#  'SG2_32124063',
#  'SG2_31855782',
#  'SG2_31743022',
#  'SG2_31696294',
#  'SG2_31656797',
#  'SG2_31611844',
#  'SG2_31605188',
#  'SG2_31374806',
#  'SG2_31371551',
#  'SG2_31326659',
#  'SG2_31329029',
#  'SG2_31323822',
#  'SG2_31274490',
#  'SG2_31267824',
#  'SG2_31246451',
#  'SG2_31175675',
#  'SG2_31089071',
#  'SG2_31065876',
#  'SG2_30985458',
#  'SG2_30853045',
#  'SG2_30095337',
#  'SG2_30093868',
#  'SG2_30071396',
#  'SG2_30065399',
#  'SG2_30056868',
#  'SG2_30047552',
#  'SG2_30020396',
#  'SG2_30006131',
#  'SG2_30002196',
#  'SG2_29994956',
#  'SG2_29906079',
#  'SG2_29888752',
#  'SG2_29744971',
#  'SG2_29746511',
#  'SG2_29730809',
#  'SG2_29720692',
#  'SG2_29720410',
#  'SG2_29695330',
#  'SG2_29692064',
#  'SG2_29688455',
#  'SG2_29684114',
#  'SG2_29678740',
#  'SG2_29679031',
#  'SG2_29676580',
#  'SG2_29670748',
#  'SG2_29637825',
#  'SG2_29638256',
#  'SG2_29633831',
#  'SG2_29616020',
#  'SG2_29501230',
#  'SG2_29488784',
#  'SG2_29491348',
#  'SG2_29377339',
#  'SG2_29318610',
#  'SG2_29302669',
#  'SG2_29210493',
#  'SG2_29206392',
#  'SG2_29197368',
#  'SG2_29195046',
#  'SG2_29183029',
#  'SG2_29182462',
#  'SG2_29135185',
#  'SG2_29134585',
#  'SG2_29132426',
#  'SG2_29131194',
#  'SG2_29124818',
#  'SG2_29102863',
#  'SG2_29102523',
#  'SG2_29102159',
#  'SG2_29090078',
#  'SG2_29076146',
#  'SG2_29073473',
#  'SG2_29018663',
#  'SG2_29013618',
#  'SG2_29002776',
#  'SG2_29004399',
#  'SG2_29004146',
#  'SG2_29002055',
#  'SG2_28968694',
#  'SG2_28970236',
#  'SG2_28964975',
#  'SG2_28959860',
#  'SG2_28963228',
#  'SG2_28955948',
#  'SG2_28917428',
#  'SG2_28910257',
#  'SG2_28908549',
#  'SG2_28898516',
#  'SG2_28899226',
#  'SG2_28862353',
#  'SG2_28855029',
#  'SG2_28840403',
#  'SG2_28816256',
#  'SG2_28809766',
#  'SG2_28811149',
#  'SG2_28796975',
#  'SG2_28791431',
#  'SG2_28787739',
#  'SG2_28744943',
#  'SG2_28745431',
#  'SG2_28686348',
#  'SG2_28679001',
#  'SG2_28671801',
#  'SG2_28673305',
#  'SG2_28666610',
#  'SG2_28667297',
#  'SG2_28624094',
#  'SG2_28584049',
#  'SG2_28579255',
#  'SG2_28574784',
#  'SG2_28572577',
#  'SG2_28566419',
#  'SG2_28565741',
#  'SG2_28513485',
#  'SG2_28511341',
#  'SG2_28508131',
#  'SG2_28504324',
#  'SG2_28479036',
#  'SG2_28458423',
#  'SG2_28455759',
#  'SG2_28451851',
#  'SG2_28405843',
#  'SG2_28224575',
#  'SG2_28217366',
#  'SG2_28214076',
#  'SG2_28210750',
#  'SG2_28165831',
#  'SG2_28167570',
#  'SG2_28145795',
#  'SG2_28097250',
#  'SG2_28094101',
#  'SG2_28041720',
#  'SG2_28043128',
#  'SG2_28037814',
#  'SG2_28027866',
#  'SG2_28026313',
#  'SG2_28025822',
#  'SG2_27974250',
#  'SG2_27967870',
#  'SG2_27967460',
#  'SG2_27944689',
#  'SG2_27943166',
#  'SG2_27940636',
#  'SG2_27924183',
#  'SG2_27912877',
#  'SG2_27912532',
#  'SG2_27907267',
#  'SG2_27900931',
#  'SG2_27902551',
#  'SG2_27863398',
#  'SG2_27854202',
#  'SG2_27849976',
#  'SG2_27849662',
#  'SG2_27842380',
#  'SG2_27824002',
#  'SG2_27811993',
#  'SG2_27801412',
#  'SG2_27794178',
#  'SG2_27789371',
#  'SG2_27758930',
#  'SG2_27746617',
#  'SG2_27743177',
#  'SG2_27735855']

# %%
len(matches_ids)
# Out:
# 200

# %%
matches = [watcher.match.by_id(my_region, match) for match in matches_ids]

# %%
matches[0].keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
matches[0]['info'].keys()
# Out:
# dict_keys(['endOfGameResult', 'gameCreation', 'gameId', 'game_datetime', 'game_length', 'game_version', 'mapId', 'participants', 'queueId', 'queue_id', 'tft_game_type', 'tft_set_core_name', 'tft_set_number'])

# %%
matches[0]['metadata']
# Out:
# {'data_version': '5',
#  'match_id': 'SG2_34716410',
#  'participants': ['xwCmvxJA2S7qUmiA2Z97SZkCaKnxPMkvNaPir5reiBxGshE9vr6CuGVsojnAHqJ8LG9qbh82427Qhg',
#   'FyclgzlL6OD4ggulj8fYDxbVrzQNXR6xI-HGtHYhcCVk_ldn5gM3fGpD58q9ztI_UkQW6hrNQzOznw',
#   'mQz9udI2600t4PlsCOm0GCQqxM2gYwkuiRHJA8qIgg6Dc0N9dwuHtZukXsaJaGggkqTnXFnv56y7pw',
#   '4RAgBJs73zneqLzAkL33NUm2qJGvDPVPD1G_b1ocjp-5iUMCNs4ElcoTrDfXogC7RHTD_D418O9dlw',
#   'JebtD2IZsxY1XEIJrZFadvkLpecjxr8uzTbioLONJFhf-RxgLR6WfuG0iLg0ekXn33ydWhSOpOon2g',
#   '-4PcL4Gar1MusAUBcmvZosXXVEKKFeT-GY26wOaSW6N4Ug1kSXKWmv_fqOKhiHbsg6bFDcu6USADeg',
#   'GzPBNH7ouvZ8xFdIMfAQZdVlgZvnI7DeBl3RKXa7sKIf5xgg-DuH_yqK2Zb9vdRlhTGGgzkB2XW7Aw',
#   'do89aFWb4XSLdWHutKAuqybvBSC0Eo6yKMw-bntJoohbdgoLrfPvdJuAj2NRQQdBzKEFVA5SJfnK_w']}

# %%
matches[0]['info']['participants']
# Out:
# [{'augments': ['TFT10_Augment_LearningToSpell',
#    'TFT11_Augment_BehemothCrest',
#    'TFT6_Augment_Keepers2'],
#   'companion': {'content_ID': '695aeccf-59ba-40d3-be5c-0459548e7891',
#    'item_ID': 52012,
#    'skin_ID': 12,
#    'species': 'PetBunny'},
#   'gold_left': 44,
#   'last_round': 34,
#   'level': 8,
#   'missions': {'PlayerScore2': 100},
#   'placement': 5,
#   'players_eliminated': 0,
#   'puuid': 'xwCmvxJA2S7qUmiA2Z97SZkCaKnxPMkvNaPir5reiBxGshE9vr6CuGVsojnAHqJ8LG9qbh82427Qhg',
#   'time_eliminated': 2004.25390625,
#   'total_damage_to_players': 103,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Arcanist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Behemoth',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Exalted',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Fortune',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 6,
#     'style': 3,
#     'tier_current': 3,
#     'tier_total': 4},
#    {'name': 'TFT11_InkShadow',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Reaper',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Sage',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Sniper',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Caitlyn',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Zyra',
#     'itemNames': ['TFT_Item_RabadonsDeathcap',
#      'TFT_Item_SpearOfShojin',
#      'TFT_Item_GuinsoosRageblade'],
#     'name': '',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT11_Riven',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Shen',
#     'itemNames': ['TFT_Item_IonicSpark',
#      'TFT_Item_Redemption',
#      'TFT_Item_DragonsClaw'],
#     'name': '',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT11_Aatrox',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Illaoi',
#     'itemNames': ['TFT_Item_BrambleVest',
#      'TFT11_Item_BehemothEmblemItem',
#      'TFT_Item_WarmogsArmor'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Zoe',
#     'itemNames': ['TFT_Item_SpearOfShojin',
#      'TFT_Item_NeedlesslyLargeRod',
#      'TFT4_Item_OrnnMuramana'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Morgana',
#     'itemNames': ['TFT_Item_StatikkShiv'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Kayn',
#     'itemNames': ['TFT_Item_ForceOfNature'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Kayle',
#     'itemNames': ['TFT11_Storyweaver3_AS'],
#     'name': '',
#     'rarity': 9,
#     'tier': 1}]},
#  {'augments': ['TFT9_Augment_PumpingUp2',
#    'TFT11_Augment_Warden',
#    'TFT10_Augment_LittleBuddies'],
#   'companion': {'content_ID': '9e342347-81f4-43a8-8b1f-e3c50bc4896b',
#    'item_ID': 4003,
#    'skin_ID': 3,
#    'species': 'PetMiner'},
#   'gold_left': 0,
#   'last_round': 38,
#   'level': 9,
#   'missions': {'PlayerScore2': 221},
#   'placement': 2,
#   'players_eliminated': 1,
#   'puuid': 'FyclgzlL6OD4ggulj8fYDxbVrzQNXR6xI-HGtHYhcCVk_ldn5gM3fGpD58q9ztI_UkQW6hrNQzOznw',
#   'time_eliminated': 2219.146728515625,
#   'total_damage_to_players': 140,
#   'traits': [{'name': 'TFT11_Arcanist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Dryad',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Fated',
#     'num_units': 2,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_InkShadow',
#     'num_units': 2,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Mythic',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Porcelain',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Sniper',
#     'num_units': 4,
#     'style': 2,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'TFT11_Umbral',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 6,
#     'style': 3,
#     'tier_current': 3,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Jax',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Caitlyn',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Gnar',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 1},
#    {'character_id': 'TFT11_Senna',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_GargoyleStoneplate',
#      'TFT_Item_RedBuff'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Illaoi',
#     'itemNames': ['TFT_Item_GargoyleStoneplate',
#      'TFT_Item_BrambleVest',
#      'TFT_Item_SteraksGage'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Amumu',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_Bloodthirster',
#      'TFT_Item_DragonsClaw'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Aphelios',
#     'itemNames': ['TFT_Item_RapidFireCannon'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Nautilus',
#     'itemNames': ['TFT_Item_Crownguard'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Ashe',
#     'itemNames': ['TFT_Item_MadredsBloodrazor',
#      'TFT_Item_LastWhisper',
#      'TFT_Item_GuinsoosRageblade'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Sett',
#     'itemNames': ['TFT_Item_Crownguard',
#      'TFT_Item_ForceOfNature',
#      'TFT_Item_Artifact_SuspiciousTrenchCoat'],
#     'name': '',
#     'rarity': 6,
#     'tier': 2}]},
#  {'augments': ['TFT9_Augment_Formation2',
#    'TFT9_Augment_JeweledLotus',
#    'TFT9_Augment_CombatCaster'],
#   'companion': {'content_ID': 'f8a8c5c9-7355-4ca8-be02-296a5322c4a1',
#    'item_ID': 80001,
#    'skin_ID': 1,
#    'species': 'PetChibiEzreal'},
#   'gold_left': 2,
#   'last_round': 36,
#   'level': 9,
#   'missions': {'PlayerScore2': 213},
#   'placement': 3,
#   'players_eliminated': 1,
#   'puuid': 'mQz9udI2600t4PlsCOm0GCQqxM2gYwkuiRHJA8qIgg6Dc0N9dwuHtZukXsaJaGggkqTnXFnv56y7pw',
#   'time_eliminated': 2137.14111328125,
#   'total_damage_to_players': 117,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Artist',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Behemoth',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 4,
#     'style': 2,
#     'tier_current': 2,
#     'tier_total': 4},
#    {'name': 'TFT11_Dragonlord',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Fortune',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_InkShadow',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Lovers',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Mythic',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_SpiritWalker',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Trickshot',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 2},
#    {'name': 'TFT11_Umbral',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Sivir',
#     'itemNames': ['TFT_Item_InfinityEdge'],
#     'name': '',
#     'rarity': 0,
#     'tier': 1},
#    {'character_id': 'TFT11_Riven',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Teemo',
#     'itemNames': ['TFT_Item_Morellonomicon'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Aatrox',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Sylas',
#     'itemNames': ['TFT11_Item_InkshadowOx'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Kaisa',
#     'itemNames': ['TFT_Item_LastWhisper',
#      'TFT_Item_InfinityEdge',
#      'TFT_Item_HextechGunblade'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Galio',
#     'itemNames': ['TFT_Item_Redemption',
#      'TFT_Item_GargoyleStoneplate',
#      'TFT_Item_AdaptiveHelm'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Hwei',
#     'itemNames': ['TFT_Item_ForceOfNature', 'TFT_Item_NeedlesslyLargeRod'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Udyr',
#     'itemNames': [],
#     'name': '',
#     'rarity': 6,
#     'tier': 2},
#    {'character_id': 'TFT11_Xayah',
#     'itemNames': ['TFT4_Item_OrnnTheCollector',
#      'TFT_Item_InfinityEdge',
#      'TFT_Item_Deathblade'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Kayle',
#     'itemNames': ['TFT11_Storyweaver3_AS'],
#     'name': '',
#     'rarity': 9,
#     'tier': 1}]},
#  {'augments': ['TFT9_Augment_PandorasItems2',
#    'TFT9_Augment_BigGrabBag',
#    'TFT9_Augment_GiftsFromTheFallen'],
#   'companion': {'content_ID': '7aec1f33-c42a-4a38-b5c2-65ca845c0e4b',
#    'item_ID': 63010,
#    'skin_ID': 10,
#    'species': 'PetShark'},
#   'gold_left': 20,
#   'last_round': 34,
#   'level': 8,
#   'missions': {'PlayerScore2': 100},
#   'placement': 6,
#   'players_eliminated': 0,
#   'puuid': '4RAgBJs73zneqLzAkL33NUm2qJGvDPVPD1G_b1ocjp-5iUMCNs4ElcoTrDfXogC7RHTD_D418O9dlw',
#   'time_eliminated': 2006.5567626953125,
#   'total_damage_to_players': 83,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Arcanist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Behemoth',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Duelist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Fortune',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Great',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Heavenly',
#     'num_units': 6,
#     'style': 3,
#     'tier_current': 5,
#     'tier_total': 6},
#    {'name': 'TFT11_Mythic',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Reaper',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Sage',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_KhaZix',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Malphite',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Qiyana',
#     'itemNames': ['TFT_Item_ForceOfNature'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Riven',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Neeko',
#     'itemNames': ['TFT_Item_DragonsClaw',
#      'TFT_Item_Redemption',
#      'TFT_Item_BrambleVest'],
#     'name': '',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT11_Zoe',
#     'itemNames': ['TFT_Item_SpearOfShojin',
#      'TFT_Item_Morellonomicon',
#      'TFT_Item_Leviathan'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Soraka',
#     'itemNames': ['TFT_Item_RabadonsDeathcap',
#      'TFT_Item_Leviathan',
#      'TFT_Item_SpearOfShojin'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Galio',
#     'itemNames': ['TFT_Item_Artifact_LightshieldCrest', 'TFT_Item_Redemption'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_WuKong',
#     'itemNames': ['TFT_Item_Bloodthirster',
#      'TFT_Item_StatikkShiv',
#      'TFT_Item_BlueBuff'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Kayle',
#     'itemNames': ['TFT11_Storyweaver3_AP'],
#     'name': '',
#     'rarity': 9,
#     'tier': 1}]},
#  {'augments': ['TFT11_Augment_KobukoCarry',
#    'TFT10_Augment_HeavyHitters',
#    'TFT9_Augment_Martyr'],
#   'companion': {'content_ID': '7d15e4b3-de0e-43b6-bbfb-ca96615f8cc8',
#    'item_ID': 79002,
#    'skin_ID': 2,
#    'species': 'PetChibiYone'},
#   'gold_left': 11,
#   'last_round': 29,
#   'level': 8,
#   'missions': {'PlayerScore2': 87},
#   'placement': 7,
#   'players_eliminated': 0,
#   'puuid': 'JebtD2IZsxY1XEIJrZFadvkLpecjxr8uzTbioLONJFhf-RxgLR6WfuG0iLg0ekXn33ydWhSOpOon2g',
#   'time_eliminated': 1740.494384765625,
#   'total_damage_to_players': 48,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 6,
#     'style': 2,
#     'tier_current': 3,
#     'tier_total': 4},
#    {'name': 'TFT11_Duelist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Exalted',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Fated',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Fortune',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_InkShadow',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Mythic',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Umbral',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_FortuneYord',
#     'itemNames': ['TFT_Item_Redemption',
#      'TFT_Item_DragonsClaw',
#      'TFT_Item_BrambleVest'],
#     'name': '',
#     'rarity': 0,
#     'tier': 3},
#    {'character_id': 'TFT11_Riven',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Aatrox',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_TahmKench',
#     'itemNames': ['TFT_Item_GiantsBelt'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Sylas',
#     'itemNames': ['TFT_Item_RabadonsDeathcap', 'TFT_Item_Crownguard'],
#     'name': '',
#     'rarity': 4,
#     'tier': 1},
#    {'character_id': 'TFT11_Galio',
#     'itemNames': ['TFT_Item_RedBuff'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Sett',
#     'itemNames': [],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Irelia',
#     'itemNames': ['TFT_Item_HextechGunblade',
#      'TFT_Item_InfinityEdge',
#      'TFT_Item_GuinsoosRageblade'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Kayle',
#     'itemNames': ['TFT11_Storyweaver3_AS'],
#     'name': '',
#     'rarity': 9,
#     'tier': 1}]},
#  {'augments': ['TFT10_Augment_LearningToSpell',
#    'TFT9_Augment_TwoHealthy',
#    'TFT9_Augment_Formation2'],
#   'companion': {'content_ID': 'e11fc781-0df7-4087-acd1-57264abefe58',
#    'item_ID': 27027,
#    'skin_ID': 27,
#    'species': 'PetChoncc'},
#   'gold_left': 1,
#   'last_round': 35,
#   'level': 8,
#   'missions': {'PlayerScore2': 206},
#   'placement': 4,
#   'players_eliminated': 1,
#   'puuid': '-4PcL4Gar1MusAUBcmvZosXXVEKKFeT-GY26wOaSW6N4Ug1kSXKWmv_fqOKhiHbsg6bFDcu6USADeg',
#   'time_eliminated': 2069.6328125,
#   'total_damage_to_players': 102,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Arcanist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Behemoth',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Dragonlord',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Exalted',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Fortune',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 4,
#     'style': 2,
#     'tier_current': 2,
#     'tier_total': 4},
#    {'name': 'TFT11_InkShadow',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Lovers',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Sage',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Umbral',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Zyra',
#     'itemNames': ['TFT_Item_StatikkShiv'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Riven',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Shen',
#     'itemNames': ['TFT_Item_FrozenHeart'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Aatrox',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Illaoi',
#     'itemNames': ['TFT_Item_FrozenHeart',
#      'TFT_Item_NightHarvester',
#      'TFT_Item_Redemption'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Zoe',
#     'itemNames': ['TFT_Item_SpearOfShojin',
#      'TFT_Item_JeweledGauntlet',
#      'TFT_Item_Leviathan'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Sylas',
#     'itemNames': [],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Morgana',
#     'itemNames': ['TFT_Item_RapidFireCannon', 'TFT_Item_AdaptiveHelm'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Rakan',
#     'itemNames': ['TFT7_Item_ShimmerscaleDiamondHands',
#      'TFT_Item_ForceOfNature'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Kayle',
#     'itemNames': ['TFT11_Storyweaver3_AP'],
#     'name': '',
#     'rarity': 9,
#     'tier': 1}]},
#  {'augments': ['TFT11_Augment_Porcelain',
#    'TFT9_Augment_CombatCaster',
#    'TFT11_Augment_PorcelainCrest'],
#   'companion': {'content_ID': '94676cb6-1166-494b-8827-9cb8a6f88a31',
#    'item_ID': 17004,
#    'skin_ID': 4,
#    'species': 'PetBuglet'},
#   'gold_left': 3,
#   'last_round': 38,
#   'level': 9,
#   'missions': {'PlayerScore2': 221},
#   'placement': 1,
#   'players_eliminated': 2,
#   'puuid': 'GzPBNH7ouvZ8xFdIMfAQZdVlgZvnI7DeBl3RKXa7sKIf5xgg-DuH_yqK2Zb9vdRlhTGGgzkB2XW7Aw',
#   'time_eliminated': 2219.146728515625,
#   'total_damage_to_players': 178,
#   'traits': [{'name': 'TFT11_Arcanist',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Behemoth',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Dragonlord',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Dryad',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Exalted',
#     'num_units': 5,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 2},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Invoker',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Mythic',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Porcelain',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'TFT11_Sage',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_RekSai',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 1},
#    {'character_id': 'TFT11_Zyra',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Janna',
#     'itemNames': ['TFT_Item_GuinsoosRageblade',
#      'TFT_Item_Leviathan',
#      'TFT9_Item_OrnnHorizonFocus'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Shen',
#     'itemNames': ['TFT_Item_ChainVest'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Lux',
#     'itemNames': ['TFT_Item_Leviathan',
#      'TFT_Item_GuinsoosRageblade',
#      'TFT_Item_StatikkShiv'],
#     'name': '',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT11_Diana',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_FrozenHeart',
#      'TFT_Item_GargoyleStoneplate'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Illaoi',
#     'itemNames': ['TFT_Item_BrambleVest',
#      'TFT11_Item_PorcelainEmblemItem',
#      'TFT_Item_NightHarvester'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Amumu',
#     'itemNames': ['TFT_Item_DragonsClaw',
#      'TFT_Item_BrambleVest',
#      'TFT_Item_WarmogsArmor'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Lillia',
#     'itemNames': ['TFT_Item_StatikkShiv'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Lissandra',
#     'itemNames': ['TFT_Item_ForceOfNature'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1}]},
#  {'augments': ['TFT10_Augment_Scapegoat',
#    'TFT9_Augment_BigGrabBag',
#    'TFT10_Augment_InspiringEpitaph'],
#   'companion': {'content_ID': '3f425bda-6328-4519-ac76-b8efe7fb620c',
#    'item_ID': 18016,
#    'skin_ID': 16,
#    'species': 'PetGargoyle'},
#   'gold_left': 0,
#   'last_round': 28,
#   'level': 9,
#   'missions': {'PlayerScore2': 83},
#   'placement': 8,
#   'players_eliminated': 0,
#   'puuid': 'do89aFWb4XSLdWHutKAuqybvBSC0Eo6yKMw-bntJoohbdgoLrfPvdJuAj2NRQQdBzKEFVA5SJfnK_w',
#   'time_eliminated': 1677.2508544921875,
#   'total_damage_to_players': 36,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Arcanist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Dragonlord',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Duelist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Fortune',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Lovers',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Porcelain',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Sage',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 6,
#     'style': 2,
#     'tier_current': 2,
#     'tier_total': 4},
#    {'name': 'TFT11_Trickshot',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Warden',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Sivir',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Garen',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Zyra',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 1},
#    {'character_id': 'TFT11_Riven',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 1},
#    {'character_id': 'TFT11_Zoe',
#     'itemNames': ['TFT_Item_Leviathan',
#      'TFT_Item_RapidFireCannon',
#      'TFT_Item_RabadonsDeathcap'],
#     'name': '',
#     'rarity': 2,
#     'tier': 1},
#    {'character_id': 'TFT11_LeeSin',
#     'itemNames': ['TFT_Item_TitansResolve',
#      'TFT_Item_SteraksGage',
#      'TFT_Item_Bloodthirster'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Galio',
#     'itemNames': ['TFT_Item_NightHarvester',
#      'TFT_Item_Crownguard',
#      'TFT_Item_Redemption'],
#     'name': '',
#     'rarity': 4,
#     'tier': 1},
#    {'character_id': 'TFT11_Lissandra',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_Deathblade',
#      'TFT_Item_RapidFireCannon'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Rakan',
#     'itemNames': ['TFT_Item_Morellonomicon'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Kayle',
#     'itemNames': ['TFT11_Storyweaver5_AP', 'TFT11_Storyweaver3_Support'],
#     'name': '',
#     'rarity': 9,
#     'tier': 2}]}]

# %%
my_region = 'sg2'
summoner_name = 'Siden'


try:

  # Extract match IDs from the history
  match_ids = [match['gameId'] for match in match_history['matches']]

  # Loop through each match ID
  for match in matches_ids:
    # Get data for the current match
    match_data = watcher.tft.match.by_id(my_region, match_id)

    # Find your participant ID based on matching puuids
    participant_id = None
    for i, participant in enumerate(match_data['info']['participants']):
      if participant['puuid'] == my_puuid:
        participant_id = i
        break  # Exit the loop after finding your puuid

    # Check if participant ID was found
    if participant_id is None:
      print(f"Participant ID not found for match {match_id}")
      continue  # Skip to the next match if not found

    # Access data for yourself (using the participant ID)
    participant_info = match_data['info']['participants'][participant_id]
    items = participant_info['items']  # List of item IDs
    units = participant_info['units']  # List of unit data (including traits)
    # Augments data is not directly available through the API

    # Process the retrieved data for items, units, and traits (as applicable)
    print(f"Match ID: {match_id}")
    print("Items:", items)
    print("Units:", units)
    # ...

except (ConnectionError) as e:
  # Handle connection errors
  print("Error:", e)
  print("An error occurred while connecting to the API. Please check your internet connection, firewall settings, or the Riot Games API status.")

# %%
my_match_data = matches[0]['info']['participants'][matches[0]['metadata']['participants'].index(puuid)]

# %%
def find_participant_by_puuid(match, puuid):
  for participant in match['info']['participants']:
    if participant['puuid'] == puuid:
      return participant
  return None  # Participant not found

my_match_data = find_participant_by_puuid(matches[0], puuid)

# %%
my_match_data
# Out:
# {'augments': ['TFT11_Augment_Porcelain',
#   'TFT9_Augment_CombatCaster',
#   'TFT11_Augment_PorcelainCrest'],
#  'companion': {'content_ID': '94676cb6-1166-494b-8827-9cb8a6f88a31',
#   'item_ID': 17004,
#   'skin_ID': 4,
#   'species': 'PetBuglet'},
#  'gold_left': 3,
#  'last_round': 38,
#  'level': 9,
#  'missions': {'PlayerScore2': 221},
#  'placement': 1,
#  'players_eliminated': 2,
#  'puuid': 'GzPBNH7ouvZ8xFdIMfAQZdVlgZvnI7DeBl3RKXa7sKIf5xgg-DuH_yqK2Zb9vdRlhTGGgzkB2XW7Aw',
#  'time_eliminated': 2219.146728515625,
#  'total_damage_to_players': 178,
#  'traits': [{'name': 'TFT11_Arcanist',
#    'num_units': 3,
#    'style': 1,
#    'tier_current': 1,
#    'tier_total': 4},
#   {'name': 'TFT11_Behemoth',
#    'num_units': 1,
#    'style': 0,
#    'tier_current': 0,
#    'tier_total': 4},
#   {'name': 'TFT11_Bruiser',
#    'num_units': 1,
#    'style': 0,
#    'tier_current': 0,
#    'tier_total': 4},
#   {'name': 'TFT11_Dragonlord',
#    'num_units': 2,
#    'style': 1,
#    'tier_current': 1,
#    'tier_total': 4},
#   {'name': 'TFT11_Dryad',
#    'num_units': 1,
#    'style': 0,
#    'tier_current': 0,
#    'tier_total': 3},
#   {'name': 'TFT11_Exalted',
#    'num_units': 5,
#    'style': 3,
#    'tier_current': 2,
#    'tier_total': 2},
#   {'name': 'TFT11_Ghostly',
#    'num_units': 2,
#    'style': 1,
#    'tier_current': 1,
#    'tier_total': 4},
#   {'name': 'TFT11_Invoker',
#    'num_units': 2,
#    'style': 1,
#    'tier_current': 1,
#    'tier_total': 3},
#   {'name': 'TFT11_Mythic',
#    'num_units': 1,
#    'style': 0,
#    'tier_current': 0,
#    'tier_total': 4},
#   {'name': 'TFT11_Porcelain',
#    'num_units': 4,
#    'style': 3,
#    'tier_current': 2,
#    'tier_total': 3},
#   {'name': 'TFT11_Sage',
#    'num_units': 2,
#    'style': 1,
#    'tier_current': 1,
#    'tier_total': 4},
#   {'name': 'TFT11_Storyweaver',
#    'num_units': 1,
#    'style': 0,
#    'tier_current': 0,
#    'tier_total': 4},
#   {'name': 'TFT11_Warden',
#    'num_units': 2,
#    'style': 1,
#    'tier_current': 1,
#    'tier_total': 4}],
#  'units': [{'character_id': 'TFT11_RekSai',
#    'itemNames': [],
#    'name': '',
#    'rarity': 0,
#    'tier': 1},
#   {'character_id': 'TFT11_Zyra',
#    'itemNames': [],
#    'name': '',
#    'rarity': 1,
#    'tier': 2},
#   {'character_id': 'TFT11_Janna',
#    'itemNames': ['TFT_Item_GuinsoosRageblade',
#     'TFT_Item_Leviathan',
#     'TFT9_Item_OrnnHorizonFocus'],
#    'name': '',
#    'rarity': 1,
#    'tier': 2},
#   {'character_id': 'TFT11_Shen',
#    'itemNames': ['TFT_Item_ChainVest'],
#    'name': '',
#    'rarity': 1,
#    'tier': 2},
#   {'character_id': 'TFT11_Lux',
#    'itemNames': ['TFT_Item_Leviathan',
#     'TFT_Item_GuinsoosRageblade',
#     'TFT_Item_StatikkShiv'],
#    'name': '',
#    'rarity': 1,
#    'tier': 3},
#   {'character_id': 'TFT11_Diana',
#    'itemNames': ['TFT_Item_ThiefsGloves',
#     'TFT_Item_FrozenHeart',
#     'TFT_Item_GargoyleStoneplate'],
#    'name': '',
#    'rarity': 2,
#    'tier': 2},
#   {'character_id': 'TFT11_Illaoi',
#    'itemNames': ['TFT_Item_BrambleVest',
#     'TFT11_Item_PorcelainEmblemItem',
#     'TFT_Item_NightHarvester'],
#    'name': '',
#    'rarity': 2,
#    'tier': 2},
#   {'character_id': 'TFT11_Amumu',
#    'itemNames': ['TFT_Item_DragonsClaw',
#     'TFT_Item_BrambleVest',
#     'TFT_Item_WarmogsArmor'],
#    'name': '',
#    'rarity': 2,
#    'tier': 2},
#   {'character_id': 'TFT11_Lillia',
#    'itemNames': ['TFT_Item_StatikkShiv'],
#    'name': '',
#    'rarity': 4,
#    'tier': 2},
#   {'character_id': 'TFT11_Lissandra',
#    'itemNames': ['TFT_Item_ForceOfNature'],
#    'name': '',
#    'rarity': 6,
#    'tier': 1}]}

# %%
my_match_data.keys()
# Out:
# dict_keys(['augments', 'companion', 'gold_left', 'last_round', 'level', 'missions', 'placement', 'players_eliminated', 'puuid', 'time_eliminated', 'total_damage_to_players', 'traits', 'units'])

# %%
my_match_data['units']
# Out:
# [{'character_id': 'TFT11_Caitlyn',
#   'itemNames': ['TFT_Item_SpearOfShojin',
#    'TFT_Item_InfinityEdge',
#    'TFT_Item_StatikkShiv'],
#   'name': '',
#   'rarity': 0,
#   'tier': 2},
#  {'character_id': 'TFT11_Aatrox',
#   'itemNames': [],
#   'name': '',
#   'rarity': 1,
#   'tier': 2},
#  {'character_id': 'TFT11_Senna',
#   'itemNames': ['TFT5_Item_DeathbladeRadiant',
#    'TFT_Item_LastWhisper',
#    'TFT_Item_MadredsBloodrazor'],
#   'name': '',
#   'rarity': 1,
#   'tier': 3},
#  {'character_id': 'TFT11_Shen',
#   'itemNames': ['TFT7_Item_ShimmerscaleDiamondHands',
#    'TFT11_Item_InkshadowPig',
#    'TFT_Item_GargoyleStoneplate'],
#   'name': '',
#   'rarity': 1,
#   'tier': 3},
#  {'character_id': 'TFT11_Illaoi',
#   'itemNames': ['TFT_Item_RedBuff',
#    'TFT_Item_Crownguard',
#    'TFT_Item_WarmogsArmor'],
#   'name': '',
#   'rarity': 2,
#   'tier': 3},
#  {'character_id': 'TFT11_Morgana',
#   'itemNames': [],
#   'name': '',
#   'rarity': 4,
#   'tier': 2},
#  {'character_id': 'TFT11_Kayn',
#   'itemNames': ['TFT_Item_UnstableConcoction'],
#   'name': '',
#   'rarity': 4,
#   'tier': 2},
#  {'character_id': 'TFT11_Lillia',
#   'itemNames': [],
#   'name': '',
#   'rarity': 4,
#   'tier': 1},
#  {'character_id': 'TFT11_Udyr',
#   'itemNames': ['TFT_Item_IonicSpark',
#    'TFT_Item_UnstableConcoction',
#    'TFT_Item_TitansResolve'],
#   'name': '',
#   'rarity': 6,
#   'tier': 2}]

# %%
my_match_data['traits']
# Out:
# [{'name': 'TFT11_Arcanist',
#   'num_units': 2,
#   'style': 1,
#   'tier_current': 1,
#   'tier_total': 4},
#  {'name': 'TFT11_Behemoth',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 3},
#  {'name': 'TFT11_Dragonlord',
#   'num_units': 2,
#   'style': 1,
#   'tier_current': 1,
#   'tier_total': 4},
#  {'name': 'TFT11_Dryad',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 3},
#  {'name': 'TFT11_Exalted',
#   'num_units': 3,
#   'style': 2,
#   'tier_current': 1,
#   'tier_total': 2},
#  {'name': 'TFT11_Ghostly',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 4},
#  {'name': 'TFT11_Invoker',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 3},
#  {'name': 'TFT11_Porcelain',
#   'num_units': 6,
#   'style': 3,
#   'tier_current': 3,
#   'tier_total': 3},
#  {'name': 'TFT11_Sage',
#   'num_units': 2,
#   'style': 1,
#   'tier_current': 1,
#   'tier_total': 4},
#  {'name': 'TFT11_Storyweaver',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 4},
#  {'name': 'TFT11_Warden',
#   'num_units': 2,
#   'style': 1,
#   'tier_current': 1,
#   'tier_total': 3}]

# %%
matches[0]['info']['participants']
# Out:
# [{'augments': ['TFT9_Augment_BardPlaybook3',
#    'TFT7_Augment_LuckyGlovesPlus',
#    'TFT9_Augment_PandorasRadiantBox'],
#   'companion': {'content_ID': '94676cb6-1166-494b-8827-9cb8a6f88a31',
#    'item_ID': 17004,
#    'skin_ID': 4,
#    'species': 'PetBuglet'},
#   'gold_left': 52,
#   'last_round': 41,
#   'level': 9,
#   'missions': {'PlayerScore2': 238},
#   'placement': 2,
#   'players_eliminated': 2,
#   'puuid': 'GzPBNH7ouvZ8xFdIMfAQZdVlgZvnI7DeBl3RKXa7sKIf5xgg-DuH_yqK2Zb9vdRlhTGGgzkB2XW7Aw',
#   'time_eliminated': 2385.96484375,
#   'total_damage_to_players': 202,
#   'traits': [{'name': 'TFT11_Arcanist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Behemoth',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Dryad',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'TFT11_Fated',
#     'num_units': 7,
#     'style': 3,
#     'tier_current': 3,
#     'tier_total': 4},
#    {'name': 'TFT11_Invoker',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Reaper',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Umbral',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Ahri',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_RekSai',
#     'itemNames': ['TFT_Item_Redemption', 'TFT11_Item_FatedEmblemItem'],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Kindred',
#     'itemNames': ['TFT_Item_RapidFireCannon',
#      'TFT_Item_Leviathan',
#      'TFT_Item_SpearOfShojin'],
#     'name': '',
#     'rarity': 1,
#     'tier': 1},
#    {'character_id': 'TFT11_Thresh',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_BrambleVest',
#      'TFT_Item_Redemption'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Syndra',
#     'itemNames': ['TFT5_Item_BlueBuffRadiant',
#      'TFT5_Item_RabadonsDeathcapRadiant',
#      'TFT_Item_Leviathan'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Sylas',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_IonicSpark',
#      'TFT_Item_TitansResolve'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Ornn',
#     'itemNames': ['TFT_Item_IonicSpark',
#      'TFT_Item_BrambleVest',
#      'TFT_Item_FrozenHeart'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Sett',
#     'itemNames': ['TFT_Item_Bloodthirster',
#      'TFT_Item_GuardianAngel',
#      'TFT_Item_Quicksilver'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1},
#    {'character_id': 'TFT11_Azir',
#     'itemNames': ['TFT11_Item_FatedEmblemItem',
#      'TFT_Item_SpearOfShojin',
#      'TFT_Item_RabadonsDeathcap'],
#     'name': '',
#     'rarity': 6,
#     'tier': 1}]},
#  {'augments': ['TFT9_Augment_StarterKit',
#    'TFT11_Augment_RadiantRefactor',
#    'TFT11_Augment_ReaperCrown'],
#   'companion': {'content_ID': 'ba753e84-0f33-4b84-9f39-055f8bf107b3',
#    'item_ID': 79001,
#    'skin_ID': 1,
#    'species': 'PetChibiYone'},
#   'gold_left': 0,
#   'last_round': 32,
#   'level': 8,
#   'missions': {'PlayerScore2': 96},
#   'placement': 6,
#   'players_eliminated': 1,
#   'puuid': '0OLe6lFYBxJKhFMzkf_Is0DFYr2o5x7EnHZhYE3UAnjdBehi9VTlicimK5qgFWkvNhjRhQ99y464Cg',
#   'time_eliminated': 1914.7379150390625,
#   'total_damage_to_players': 66,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Arcanist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Behemoth',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Dryad',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Duelist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Great',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Heavenly',
#     'num_units': 6,
#     'style': 3,
#     'tier_current': 5,
#     'tier_total': 6},
#    {'name': 'TFT11_Mythic',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Reaper',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 2},
#    {'name': 'TFT11_Sage',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Umbral',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_KhaZix',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Malphite',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Qiyana',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Neeko',
#     'itemNames': ['TFT_Item_IonicSpark'],
#     'name': '',
#     'rarity': 1,
#     'tier': 1},
#    {'character_id': 'TFT11_Yone',
#     'itemNames': ['TFT_Item_Bloodthirster',
#      'TFT_Item_TitansResolve',
#      'TFT_Item_Quicksilver'],
#     'name': '',
#     'rarity': 2,
#     'tier': 3},
#    {'character_id': 'TFT11_Soraka',
#     'itemNames': ['TFT_Item_Morellonomicon', 'TFT11_Item_DryadEmblemItem'],
#     'name': '',
#     'rarity': 2,
#     'tier': 1},
#    {'character_id': 'TFT11_Kayn',
#     'itemNames': ['TFT5_Item_HandOfJusticeRadiant',
#      'TFT_Item_LastWhisper',
#      'TFT_Item_GuardianAngel'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_WuKong',
#     'itemNames': ['TFT_Item_SteraksGage',
#      'TFT_Item_UnstableConcoction',
#      'TFT11_Item_ReaperEmblemItem'],
#     'name': '',
#     'rarity': 6,
#     'tier': 2}]},
#  {'augments': ['TFT6_Augment_GachaAddict',
#    'TFT11_Augment_PorcelainCrown',
#    'TFT11_Augment_SageCrown'],
#   'companion': {'content_ID': 'f2ec1cfe-c74a-4fe5-9435-1a47b5f1d401',
#    'item_ID': 38003,
#    'skin_ID': 3,
#    'species': 'PetChibiYasuo'},
#   'gold_left': 0,
#   'last_round': 34,
#   'level': 8,
#   'missions': {'PlayerScore2': 101},
#   'placement': 5,
#   'players_eliminated': 0,
#   'puuid': 'S8oKU32DTZOIRhImIkwXzYx5svdR4fwdAkBCZFUd59Q1frXmkKGeepbYTT2U5F1bYBkjnIeOgQOzhw',
#   'time_eliminated': 2037.2098388671875,
#   'total_damage_to_players': 89,
#   'traits': [{'name': 'TFT11_Arcanist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Dragonlord',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Exalted',
#     'num_units': 2,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Fortune',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Invoker',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Porcelain',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'TFT11_Sage',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 3,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Zyra',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Janna',
#     'itemNames': ['TFT_Item_AdaptiveHelm', 'TFT_Item_GuinsoosRageblade'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Lux',
#     'itemNames': ['TFT_Item_SpearOfShojin',
#      'TFT_Item_JeweledGauntlet',
#      'TFT_Item_Leviathan'],
#     'name': '',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT11_Diana',
#     'itemNames': ['TFT11_Item_PorcelainEmblemItem', 'TFT_Item_AdaptiveHelm'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Illaoi',
#     'itemNames': ['TFT11_Item_PorcelainEmblemItem',
#      'TFT11_Item_SageEmblemItem'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Amumu',
#     'itemNames': ['TFT_Item_NightHarvester',
#      'TFT_Item_GargoyleStoneplate',
#      'TFT_Item_AdaptiveHelm'],
#     'name': '',
#     'rarity': 2,
#     'tier': 3},
#    {'character_id': 'TFT11_Morgana',
#     'itemNames': ['TFT_Item_Morellonomicon', 'TFT_Item_JeweledGauntlet'],
#     'name': '',
#     'rarity': 4,
#     'tier': 1},
#    {'character_id': 'TFT11_Annie',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_TitansResolve',
#      'TFT_Item_LastWhisper'],
#     'name': '',
#     'rarity': 4,
#     'tier': 1}]},
#  {'augments': ['TFT7_Augment_LivingForge',
#    'TFT9_Augment_UnleashedArcana',
#    'TFT11_Augment_AltruistCrown'],
#   'companion': {'content_ID': '7d785920-c646-4845-bcd1-a6bfa206a90b',
#    'item_ID': 6062,
#    'skin_ID': 62,
#    'species': 'PetPenguKnight'},
#   'gold_left': 17,
#   'last_round': 28,
#   'level': 7,
#   'missions': {'PlayerScore2': 84},
#   'placement': 7,
#   'players_eliminated': 0,
#   'puuid': '4Ra5IluahMGMuxVjwy_X9h8hw6wtqXj_dPBcbjpFL9IJlYWudqCWgSv0PDcqfQ8UEuc1VtS1o8Kvcg',
#   'time_eliminated': 1684.62939453125,
#   'total_damage_to_players': 49,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 3,
#     'style': 2,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'TFT11_Arcanist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Fortune',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Heavenly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 6},
#    {'name': 'TFT11_Mythic',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Trickshot',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 2}],
#   'units': [{'character_id': 'TFT11_Sivir',
#     'itemNames': ['TFT_Item_ZekesHerald'],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Riven',
#     'itemNames': ['TFT4_Item_OrnnDeathsDefiance',
#      'TFT_Item_Bloodthirster',
#      'TFT_Item_TitansResolve'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Neeko',
#     'itemNames': ['TFT_Item_IonicSpark', 'TFT11_Item_AltruistEmblemItem'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_TahmKench',
#     'itemNames': ['TFT4_Item_OrnnEternalWinter',
#      'TFT_Item_NightHarvester',
#      'TFT4_Item_OrnnAnimaVisage'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Zoe',
#     'itemNames': ['TFT_Item_RabadonsDeathcap', 'TFT_Item_HextechGunblade'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Bard',
#     'itemNames': ['TFT_Item_Artifact_WitsEnd',
#      'TFT_Item_GuinsoosRageblade',
#      'TFT_Item_GuinsoosRageblade'],
#     'name': '',
#     'rarity': 2,
#     'tier': 3},
#    {'character_id': 'TFT11_Soraka',
#     'itemNames': ['TFT_Item_SpearOfShojin',
#      'TFT_Item_Leviathan',
#      'TFT_Item_JeweledGauntlet'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Kayle',
#     'itemNames': ['TFT11_Storyweaver3_AS'],
#     'name': '',
#     'rarity': 9,
#     'tier': 1}]},
#  {'augments': ['TFT11_Augment_DragonlordCrown',
#    'TFT6_Augment_ForceOfNature',
#    'TFT11_Augment_AltruistCrown'],
#   'companion': {'content_ID': '4de10c0b-a837-46a8-8091-8b88f5d1462e',
#    'item_ID': 30,
#    'skin_ID': 30,
#    'species': 'PetTFTAvatar'},
#   'gold_left': 0,
#   'last_round': 36,
#   'level': 8,
#   'missions': {'PlayerScore2': 217},
#   'placement': 3,
#   'players_eliminated': 1,
#   'puuid': 'PWo3Ou-nX_0ZZo1_PNWP7bGRiNUm5FRtEzOfdaBdnzPtLz_O8iJqRgFGnilBbv9nmNpMweTxESc0kg',
#   'time_eliminated': 2170.18994140625,
#   'total_damage_to_players': 142,
#   'traits': [{'name': 'TFT11_Altruist',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 3,
#     'tier_total': 3},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Dragonlord',
#     'num_units': 5,
#     'style': 3,
#     'tier_current': 4,
#     'tier_total': 4},
#    {'name': 'TFT11_Duelist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Exalted',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Heavenly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 6},
#    {'name': 'TFT11_Invoker',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Lovers',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Sage',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Zyra',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Janna',
#     'itemNames': ['TFT_Item_GuinsoosRageblade',
#      'TFT_Item_SpearOfShojin',
#      'TFT_Item_ArchangelsStaff'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Qiyana',
#     'itemNames': ['TFT11_Item_DragonlordEmblemItem'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Riven',
#     'itemNames': ['TFT_Item_TitansResolve',
#      'TFT_Item_Bloodthirster',
#      'TFT_Item_Quicksilver'],
#     'name': '',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT11_Diana',
#     'itemNames': ['TFT_Item_IonicSpark',
#      'TFT_Item_WarmogsArmor',
#      'TFT_Item_SteraksGage'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Soraka',
#     'itemNames': ['TFT_Item_InfinityEdge', 'TFT_Item_ArchangelsStaff'],
#     'name': '',
#     'rarity': 2,
#     'tier': 3},
#    {'character_id': 'TFT11_LeeSin',
#     'itemNames': ['TFT_Item_Bloodthirster',
#      'TFT11_Item_AltruistEmblemItem',
#      'TFT_Item_UnstableConcoction'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Galio',
#     'itemNames': ['TFT_Item_TearOfTheGoddess'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Rakan',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_DragonsClaw',
#      'TFT_Item_HextechGunblade'],
#     'name': '',
#     'rarity': 6,
#     'tier': 2},
#    {'character_id': 'TFT11_Kayle',
#     'itemNames': ['TFT11_Storyweaver3_AP'],
#     'name': '',
#     'rarity': 9,
#     'tier': 1}]},
#  {'augments': ['TFT6_Augment_RadiantRelics',
#    'TFT9_Augment_HedgeFundPlus',
#    'TFT6_Augment_ForceOfNature'],
#   'companion': {'content_ID': '7d785920-c646-4845-bcd1-a6bfa206a90b',
#    'item_ID': 6062,
#    'skin_ID': 62,
#    'species': 'PetPenguKnight'},
#   'gold_left': 1,
#   'last_round': 41,
#   'level': 9,
#   'missions': {'PlayerScore2': 238},
#   'placement': 1,
#   'players_eliminated': 3,
#   'puuid': 'P_xifFpah4ta_vILuhlHhJavl4yTEuccy949PdxQKIMWMWaJn9K2HySn2nEbSPWDXH9bLFY5Efi41A',
#   'time_eliminated': 2385.96484375,
#   'total_damage_to_players': 221,
#   'traits': [{'name': 'TFT11_Arcanist',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Dragonlord',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Exalted',
#     'num_units': 3,
#     'style': 2,
#     'tier_current': 1,
#     'tier_total': 2},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Great',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Heavenly',
#     'num_units': 3,
#     'style': 2,
#     'tier_current': 2,
#     'tier_total': 6},
#    {'name': 'TFT11_Invoker',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Mythic',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Sage',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 3,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 2,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_Garen',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Zyra',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Janna',
#     'itemNames': ['TFT_Item_SpearOfShojin', 'TFT_Item_GuinsoosRageblade'],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Neeko',
#     'itemNames': ['TFT_Item_Redemption',
#      'TFT_Item_Crownguard',
#      'TFT_Item_BrambleVest'],
#     'name': '',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT11_Diana',
#     'itemNames': [],
#     'name': '',
#     'rarity': 2,
#     'tier': 3},
#    {'character_id': 'TFT11_Illaoi',
#     'itemNames': ['TFT11_Item_HeavenlyEmblemItem'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Morgana',
#     'itemNames': ['TFT_Item_Morellonomicon',
#      'TFT_Item_SpearOfShojin',
#      'TFT_Item_StatikkShiv'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Lillia',
#     'itemNames': ['TFT_Item_RabadonsDeathcap',
#      'TFT5_Item_SpearOfShojinRadiant',
#      'TFT_Item_JeweledGauntlet'],
#     'name': '',
#     'rarity': 4,
#     'tier': 3},
#    {'character_id': 'TFT11_Nautilus',
#     'itemNames': ['TFT_Item_GargoyleStoneplate',
#      'TFT_Item_Artifact_LightshieldCrest',
#      'TFT_Item_GargoyleStoneplate'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_WuKong',
#     'itemNames': [],
#     'name': '',
#     'rarity': 6,
#     'tier': 2}]},
#  {'augments': ['TFT9_Augment_BardPlaybook3',
#    'TFT6_Augment_ForceOfNature',
#    'TFT11_Augment_TinyButDeadly'],
#   'companion': {'content_ID': '5897ad9f-4665-4372-8f3e-6c878adb8918',
#    'item_ID': 1,
#    'skin_ID': 1,
#    'species': 'PetTFTAvatar'},
#   'gold_left': 0,
#   'last_round': 35,
#   'level': 9,
#   'missions': {'PlayerScore2': 211},
#   'placement': 4,
#   'players_eliminated': 0,
#   'puuid': '9a2IProQDPZz2MeLcSxid2hntl0pgsfgvvVyUWduxaHuFiMvEwcn9tLZPZKM5BfrHJ9nrYm27H-eRA',
#   'time_eliminated': 2111.05078125,
#   'total_damage_to_players': 97,
#   'traits': [{'name': 'TFT11_Behemoth',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Bruiser',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Dryad',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'TFT11_Fated',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Great',
#     'num_units': 1,
#     'style': 5,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'TFT11_Heavenly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 6},
#    {'name': 'TFT11_InkShadow',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Reaper',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 2},
#    {'name': 'TFT11_Sage',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 2,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Umbral',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_KhaZix',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 1},
#    {'character_id': 'TFT11_Zyra',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 1},
#    {'character_id': 'TFT11_Kindred',
#     'itemNames': ['TFT_Item_ArchangelsStaff', 'TFT_Item_RapidFireCannon'],
#     'name': '',
#     'rarity': 1,
#     'tier': 1},
#    {'character_id': 'TFT11_Aatrox',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Yone',
#     'itemNames': ['TFT_Item_UnstableConcoction',
#      'TFT5_Item_GuardianAngelRadiant',
#      'TFT_Item_SteraksGage'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Sylas',
#     'itemNames': ['TFT_Item_Crownguard',
#      'TFT_Item_AdaptiveHelm',
#      'TFT_Item_Crownguard'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Ornn',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_AdaptiveHelm',
#      'TFT_Item_Crownguard'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Kayn',
#     'itemNames': ['TFT_Item_SteraksGage',
#      'TFT_Item_Bloodthirster',
#      'TFT_Item_GuardianAngel'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Galio',
#     'itemNames': ['TFT_Item_DragonsClaw',
#      'TFT_Item_GargoyleStoneplate',
#      'TFT_Item_Redemption'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_WuKong',
#     'itemNames': ['TFT_Item_ThiefsGloves',
#      'TFT_Item_BlueBuff',
#      'TFT_Item_GuardianAngel'],
#     'name': '',
#     'rarity': 6,
#     'tier': 2}]},
#  {'augments': ['TFT11_Augment_SniperCrown',
#    'TFT11_Augment_BaBoom',
#    'TFT9_Augment_Commander_FinalAscension'],
#   'companion': {'content_ID': '7d785920-c646-4845-bcd1-a6bfa206a90b',
#    'item_ID': 6062,
#    'skin_ID': 62,
#    'species': 'PetPenguKnight'},
#   'gold_left': 6,
#   'last_round': 28,
#   'level': 8,
#   'missions': {'PlayerScore2': 84},
#   'placement': 8,
#   'players_eliminated': 0,
#   'puuid': 'Dtz-jrj-WfRLdr2TuH7VU6ZP4w35nxvCUXZu03SBODtJu0hDiw8kt4fZtOKmfjbYJYJMWgJ5KhL_4Q',
#   'time_eliminated': 1684.679443359375,
#   'total_damage_to_players': 46,
#   'traits': [{'name': 'TFT11_Arcanist',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Exalted',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'TFT11_Fated',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Ghostly',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4},
#    {'name': 'TFT11_InkShadow',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Invoker',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Mythic',
#     'num_units': 2,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Porcelain',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'TFT11_Sniper',
#     'num_units': 6,
#     'style': 3,
#     'tier_current': 3,
#     'tier_total': 3},
#    {'name': 'TFT11_Storyweaver',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 4},
#    {'name': 'TFT11_Warden',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 4}],
#   'units': [{'character_id': 'TFT11_KogMaw',
#     'itemNames': ['TFT_Item_RabadonsDeathcap', 'TFT_Item_ZekesHerald'],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Caitlyn',
#     'itemNames': [],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Garen',
#     'itemNames': ['TFT11_Item_SniperEmblemItem'],
#     'name': '',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT11_Senna',
#     'itemNames': [],
#     'name': '',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT11_Illaoi',
#     'itemNames': [],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Aphelios',
#     'itemNames': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_Deathblade'],
#     'name': '',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT11_Nautilus',
#     'itemNames': ['TFT_Item_DragonsClaw',
#      'TFT_Item_Redemption',
#      'TFT_Item_GargoyleStoneplate'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2},
#    {'character_id': 'TFT11_Ashe',
#     'itemNames': ['TFT_Item_LastWhisper',
#      'TFT_Item_GuinsoosRageblade',
#      'TFT_Item_HextechGunblade'],
#     'name': '',
#     'rarity': 4,
#     'tier': 2}]}]

# %%
import json

def extract_and_save_participant_data(matches, my_puuid, output_file, limit=201):
  """
  Extracts participant data for the given puuid from matches and saves it to a JSON file.

  Args:
    matches: A list of match dictionaries.
    my_puuid: The puuid of the player to extract data for.
    output_file: The path to the output JSON file.
    limit: The maximum number of matches to process.
  """

  participant_data = []
  found_matches = 0

  for match in matches:
    if found_matches >= limit:
      break

    for participant in match['info']['participants']:
      if participant['puuid'] == my_puuid:
        participant_data.append({
          # Add other desired data from the participant
          'participant': participant
        })
        found_matches += 1
        break

  with open(output_file, 'w') as f:
    json.dump(participant_data, f, indent=4)

# %%
output_file = "match_data_3.json"
extract_and_save_participant_data(matches, puuid, output_file, limit=201)

# %%
my_match_data.keys()
